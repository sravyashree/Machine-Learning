# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
file_path=("C:\\Users\\shrav\\Downloads\\Visadataset - Visadataset.csv")
visa_df=pd.read_csv(file_path)
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# 1                         N             2412         2002
# 2                         Y            44444         2008
# 3                         N               98         1897
# 4                         N             1082         2005
# ...                     ...              ...          ...
# 25475                     Y             2601         2008
# 25476                     N             3274         2006
# 25477                     N             1121         1910
# 25478                     Y             1918         1887
# 25479                     N             3195         1960
#
#       region_of_employment  prevailing_wage unit_of_wage full_time_position  \
# 0                     West         592.2029         Hour                  Y
# 1                Northeast       83425.6500         Year                  Y
# 2                     West      122996.8600         Year                  Y
# 3                     West       83434.0300         Year                  Y
# 4                    South      149907.3900         Year                  Y
# ...                    ...              ...          ...                ...
# 25475                South       77092.5700         Year                  Y
# 25476            Northeast      279174.7900         Year                  Y
# 25477                South      146298.8500         Year                  N
# 25478                 West       86154.7700         Year                  Y
# 25479              Midwest       70876.9100         Year                  Y
#
#       case_status
# 0          Denied
# 1       Certified
# 2          Denied
# 3          Denied
# 4       Certified
# ...           ...
# 25475   Certified
# 25476   Certified
# 25477   Certified
# 25478   Certified
# 25479   Certified
#
# [25480 rows x 12 columns]

# %%
visa_df.isnull().sum()
# Out:
# case_id                  0
# continent                0
# education_of_employee    0
# has_job_experience       0
# requires_job_training    0
# no_of_employees          0
# yr_of_estab              0
# region_of_employment     0
# prevailing_wage          0
# unit_of_wage             0
# full_time_position       0
# case_status              0
# dtype: int64

# %%
visa_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25480 entries, 0 to 25479
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   case_id                25480 non-null  object
#  1   continent              25480 non-null  object
#  2   education_of_employee  25480 non-null  object
#  3   has_job_experience     25480 non-null  object
#  4   requires_job_training  25480 non-null  object
#  5   no_of_employees        25480 non-null  int64
#  6   yr_of_estab            25480 non-null  int64
#  7   region_of_employment   25480 non-null  object
#  8   prevailing_wage        25480 non-null  float64
#  9   unit_of_wage           25480 non-null  object
#  10  full_time_position     25480 non-null  object
#  11  case_status            25480 non-null  object
# dtypes: float64(1), int64(2), object(9)
# memory usage: 2.3+ MB

# %%
visa_df.columns
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'no_of_employees', 'yr_of_estab',
#        'region_of_employment', 'prevailing_wage', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
visa_df.dtypes
# Out:
# case_id                   object
# continent                 object
# education_of_employee     object
# has_job_experience        object
# requires_job_training     object
# no_of_employees            int64
# yr_of_estab                int64
# region_of_employment      object
# prevailing_wage          float64
# unit_of_wage              object
# full_time_position        object
# case_status               object
# dtype: object

# %%
visa_df.drop("case_id",axis=1,inplace=True)

# %%
c=[i for i in dict(visa_df.dtypes) if visa_df.dtypes[i]=="O"]
c
# Out:
# ['continent',
#  'education_of_employee',
#  'has_job_experience',
#  'requires_job_training',
#  'region_of_employment',
#  'unit_of_wage',
#  'full_time_position',
#  'case_status']

# %%
n=[i for i in dict(visa_df.dtypes) if visa_df.dtypes[i]!="O"]
n
# Out:
# ['no_of_employees', 'yr_of_estab', 'prevailing_wage']

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
for i in c:
    visa_df[i]=le.fit_transform(visa_df[i])
visa_df
# Out:
#        continent  education_of_employee  has_job_experience  \
# 0              1                      2                   0
# 1              1                      3                   1
# 2              1                      0                   0
# 3              1                      0                   0
# 4              0                      3                   1
# ...          ...                    ...                 ...
# 25475          1                      0                   1
# 25476          1                      2                   1
# 25477          1                      3                   1
# 25478          1                      3                   1
# 25479          1                      0                   1
#
#        requires_job_training  no_of_employees  yr_of_estab  \
# 0                          0            14513         2007
# 1                          0             2412         2002
# 2                          1            44444         2008
# 3                          0               98         1897
# 4                          0             1082         2005
# ...                      ...              ...          ...
# 25475                      1             2601         2008
# 25476                      0             3274         2006
# 25477                      0             1121         1910
# 25478                      1             1918         1887
# 25479                      0             3195         1960
#
#        region_of_employment  prevailing_wage  unit_of_wage  \
# 0                         4         592.2029             0
# 1                         2       83425.6500             3
# 2                         4      122996.8600             3
# 3                         4       83434.0300             3
# 4                         3      149907.3900             3
# ...                     ...              ...           ...
# 25475                     3       77092.5700             3
# 25476                     2      279174.7900             3
# 25477                     3      146298.8500             3
# 25478                     4       86154.7700             3
# 25479                     1       70876.9100             3
#
#        full_time_position  case_status
# 0                       1            1
# 1                       1            0
# 2                       1            1
# 3                       1            1
# 4                       1            0
# ...                   ...          ...
# 25475                   1            0
# 25476                   1            0
# 25477                   0            0
# 25478                   1            0
# 25479                   1            0
#
# [25480 rows x 11 columns]

# %%
corr=visa_df.corr(numeric_only=True)
corr
# Out:
#                        continent  education_of_employee  has_job_experience  \
# continent               1.000000               0.000813           -0.005431
# education_of_employee   0.000813               1.000000            0.010948
# has_job_experience     -0.005431               0.010948            1.000000
# requires_job_training   0.035175              -0.052972           -0.112195
# no_of_employees         0.009647               0.016189            0.007829
# yr_of_estab            -0.027108              -0.006935            0.000821
# region_of_employment    0.053707              -0.104824            0.020860
# prevailing_wage        -0.108609               0.047208           -0.016216
# unit_of_wage           -0.089615               0.029335            0.125457
# full_time_position      0.007234              -0.158681            0.041964
# case_status             0.017606              -0.100919           -0.192162
#
#                        requires_job_training  no_of_employees  yr_of_estab  \
# continent                           0.035175         0.009647    -0.027108
# education_of_employee              -0.052972         0.016189    -0.006935
# has_job_experience                 -0.112195         0.007829     0.000821
# requires_job_training               1.000000        -0.005545    -0.006490
# no_of_employees                    -0.005545         1.000000    -0.017770
# yr_of_estab                        -0.006490        -0.017770     1.000000
# region_of_employment                0.114433         0.011801    -0.003968
# prevailing_wage                     0.054945        -0.009523     0.012342
# unit_of_wage                        0.083720         0.019549     0.042375
# full_time_position                  0.104590        -0.010472     0.009318
# case_status                        -0.008423        -0.008677    -0.008597
#
#                        region_of_employment  prevailing_wage  unit_of_wage  \
# continent                          0.053707        -0.108609     -0.089615
# education_of_employee             -0.104824         0.047208      0.029335
# has_job_experience                 0.020860        -0.016216      0.125457
# requires_job_training              0.114433         0.054945      0.083720
# no_of_employees                    0.011801        -0.009523      0.019549
# yr_of_estab                       -0.003968         0.012342      0.042375
# region_of_employment               1.000000        -0.103105     -0.013402
# prevailing_wage                   -0.103105         1.000000      0.416986
# unit_of_wage                      -0.013402         0.416986      1.000000
# full_time_position                 0.031202        -0.197729     -0.099309
# case_status                        0.053490        -0.076198     -0.207528
#
#                        full_time_position  case_status
# continent                        0.007234     0.017606
# education_of_employee           -0.158681    -0.100919
# has_job_experience               0.041964    -0.192162
# requires_job_training            0.104590    -0.008423
# no_of_employees                 -0.010472    -0.008677
# yr_of_estab                      0.009318    -0.008597
# region_of_employment             0.031202     0.053490
# prevailing_wage                 -0.197729    -0.076198
# unit_of_wage                    -0.099309    -0.207528
# full_time_position               1.000000     0.012711
# case_status                      0.012711     1.000000

# %%
c
# Out:
# ['continent',
#  'education_of_employee',
#  'has_job_experience',
#  'requires_job_training',
#  'region_of_employment',
#  'unit_of_wage',
#  'full_time_position',
#  'case_status']

# %%
plt.figure(figsize=(20,20))
sns.heatmap(corr,annot=True)
# Out:
# <Axes: >

# %%
X=visa_df.drop("case_status",axis=1)
y=visa_df["case_status"]

# %%
X.shape,y.shape
# Out:
# ((25480, 10), (25480,))

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=0)

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (20384, 10)
# (5096, 10)
# (20384,)
# (5096,)

# %%
from scipy import stats

# Define the columns for which you want to remove outliers
selected_columns = ["no_of_employees","yr_of_estab","prevailing_wage"]

# Calculate the Z-scores for the selected columns in the training data
z_scores = np.abs(stats.zscore(X_train[selected_columns]))

# Set a threshold value for outlier detection (e.g., 3)
threshold = 3

# Find the indices of outliers based on the threshold
outlier_indices = np.where(z_scores > threshold)[0]

# Remove the outliers from the training data
X_train = X_train.drop(X_train.index[outlier_indices])
y_train = y_train.drop(y_train.index[outlier_indices])

# %%
n
# Out:
# ['no_of_employees', 'yr_of_estab', 'prevailing_wage']

# %% [markdown]
# **decission tree**

# %%
from sklearn.tree import DecisionTreeClassifier
dtree=DecisionTreeClassifier()
dtree.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred_dt=dtree.predict(X_test)
y_pred_dt
# Out:
# array([0, 0, 0, ..., 1, 1, 0])

# %%
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, classification_report
acc_dt= round(accuracy_score(y_test,y_pred_dt)*100,2)
f1_dt=round(f1_score(y_test,y_pred_dt),2)
precision_dt=round(precision_score(y_test,y_pred_dt),2)
recall_dt=round(recall_score(y_test,y_pred_dt),2)
print("accuray is:",acc_dt)
print("F1 is:",f1_dt)
print("Precision is:",precision_dt)
print("Recall is:",recall_dt)
# Out:
# accuray is: 64.64
# F1 is: 0.49
# Precision is: 0.48
# Recall is: 0.5

# %%
from sklearn.metrics import confusion_matrix,ConfusionMatrixDisplay
cmt=confusion_matrix(y_test,y_pred_dt)

disp=ConfusionMatrixDisplay(confusion_matrix=cmt,
                            display_labels = [False, True])
disp.plot()
plt.grid(False)
plt.show()
tn, fp, fn, tp = confusion_matrix(y_test,y_pred_dt).ravel()
print("True negative:",tn)
print("False postive:",fp)
print("False negative:",fn)
print("True postive:",tp)
# Out:
# True negative: 2434
# False postive: 950
# False negative: 852
# True postive: 860

# %%
from sklearn.metrics import roc_curve
y_dt_pred_prob=dtree.predict_proba(X_test)[:,1]   # Class-1 probabilities
fpr,tpr,threshold=roc_curve(y_test,y_dt_pred_prob) 
plt.plot(fpr,tpr)

# %%
X=visa_df.drop("case_status",axis=1)
y=visa_df["case_status"]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=0)

# %%
from scipy import stats
selected_columns=["no_of_employees","yr_of_estab","prevailing_wage"]
z_scores=np.abs(stats.zscore(X_train[selected_columns]))
threshold=3
outlier_indices = np.where(z_scores > threshold)[0]
X_train = X_train.drop(X_train.index[outlier_indices])
y_train = y_train.drop(y_train.index[outlier_indices])

# %%
from sklearn.linear_model import LogisticRegression
logtree=LogisticRegression()
logtree.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
y_pred_log=logtree.predict(X_test)

# %%
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, classification_report
acc_log= round(accuracy_score(y_test,y_pred_log)*100,2)
f1_log=round(f1_score(y_test,y_pred_log),2)
precision_log=round(precision_score(y_test,y_pred_log),2)
recall_log=round(recall_score(y_test,y_pred_log),2)
print("accuray is:",acc_log)
print("F1 is:",f1_log)
print("Precision is:",precision_log)
print("Recall is:",recall_log)
# Out:
# accuray is: 66.41
# F1 is: 0.0
# Precision is: 0.0
# Recall is: 0.0
# C:\Users\shrav\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
from sklearn.metrics import confusion_matrix,ConfusionMatrixDisplay
cmt=confusion_matrix(y_test,y_pred_log)

disp=ConfusionMatrixDisplay(confusion_matrix=cmt,
                            display_labels = [False, True])
disp.plot()
plt.grid(False)
plt.show()


tn, fp, fn, tp = confusion_matrix(y_test,y_pred_log).ravel()
print("True negative:",tn)
print("False postive:",fp)
print("False negative:",fn)
print("True postive:",tp)
# Out:
# True negative: 3384
# False postive: 0
# False negative: 1712
# True postive: 0

# %%
y_log_pred_prob=logtree.predict_proba(X_test)[:,1]   # Class-1 probabilities
fpr,tpr,threshold=roc_curve(y_test,y_log_pred_prob) 
plt.plot(fpr,tpr)
plt.show()

# %% [markdown]
# **naive bayes**

# %%
X=visa_df.drop("case_status",axis=1)
y=visa_df["case_status"]

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.2,random_state=0)

# %%
from scipy import stats
selected_columns=["no_of_employees","yr_of_estab","prevailing_wage"]
z_scores = np.abs(stats.zscore(X_train[selected_columns]))
threshold = 3
outlier_indices = np.where(z_scores > threshold)[0]
X_train = X_train.drop(X_train.index[outlier_indices])
y_train = y_train.drop(y_train.index[outlier_indices])

# %%
from sklearn.naive_bayes import GaussianNB
NBtree=GaussianNB()
NBtree.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
y_pred_NB=NBtree.predict(X_test)

# %%
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, classification_report
acc_NB= round(accuracy_score(y_test,y_pred_NB)*100,2)
f1_NB=round(f1_score(y_test,y_pred_NB),2)
precision_NB=round(precision_score(y_test,y_pred_NB),2)
recall_NB=round(recall_score(y_test,y_pred_NB),2)
print("accuray is:",acc_NB)
print("F1 is:",f1_NB)
print("Precision is:",precision_NB)
print("Recall is:",recall_NB)
# Out:
# accuray is: 68.7
# F1 is: 0.22
# Precision is: 0.68
# Recall is: 0.13

# %%
from sklearn.metrics import confusion_matrix,ConfusionMatrixDisplay
cmt=confusion_matrix(y_test,y_pred_NB)

disp=ConfusionMatrixDisplay(confusion_matrix=cmt,
                            display_labels = [False, True])
disp.plot()
plt.grid(False)
plt.show()


tn, fp, fn, tp = confusion_matrix(y_test,y_pred_NB).ravel()
print("True negative:",tn)
print("False postive:",fp)
print("False negative:",fn)
print("True postive:",tp)
# Out:
# True negative: 3281
# False postive: 103
# False negative: 1492
# True postive: 220

# %%
y_NB_pred_prob=NBtree.predict_proba(X_test)[:,1]   # Class-1 probabilities
fpr,tpr,threshold=roc_curve(y_test,y_NB_pred_prob) 
plt.plot(fpr,tpr)
plt.show()

# %% [markdown]
# **Knn**

# %%
X=visa_df.drop("case_status",axis=1)
y=visa_df["case_status"]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=0)

# %%
from scipy import stats
selected_columns=["no_of_employees","yr_of_estab","prevailing_wage"]
z_scores=np.abs(stats.zscore(X_train[selected_columns]))
threshold=3
outlier_indices=np.where(z_scores>threshold)[0]
X_train=X_train.drop(X_train.index[outlier_indices])
y_train=y_train.drop(y_train.index[outlier_indices])

# %%
from sklearn.neighbors import KNeighborsClassifier
KNNtree=KNeighborsClassifier()
KNNtree.fit(X_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred_KNN=KNNtree.predict(X_test)

# %%
from sklearn.metrics import accuracy_score,f1_score,precision_score,recall_score,classification_report
acc_KNN=round(accuracy_score(y_test,y_pred_KNN)*100,2)
f1_KNN=round(f1_score(y_test,y_pred_KNN),2)
precision_KNN=round(precision_score(y_test,y_pred_KNN),2)
recall_KNN=round(recall_score(y_test,y_pred_KNN),2)
print("accuracy is",acc_KNN)
print("f1score is",f1_KNN)
print("precision is",precision_KNN)
print("recall is",recall_KNN)
# Out:
# accuracy is 62.42
# f1score is 0.31
# precision is 0.41
# recall is 0.26

# %%
from sklearn.metrics import confusion_matrix,ConfusionMatrixDisplay
cmt=confusion_matrix(y_test,y_pred_KNN)
disp=ConfusionMatrixDisplay(cmt,display_labels=[False,True])
disp.plot()
plt.grid(False)
plt.show()
tn,fp,fn,tp =confusion_matrix(y_test,y_pred_KNN).ravel()
print("true negative:",tn)
print("false positive:",fp)
print("false negative:",fn)
print("true positive:",tp)
# Out:
# true negative: 2741
# false positive: 643
# false negative: 1272
# true positive: 440

# %%
y_KNN_pred_prob=KNNtree.predict(X_test)
fpr,tpr,threshold =roc_curve(y_test,y_KNN_pred_prob)
plt.plot(fpr,tpr)
plt.show()

# %% [markdown]
# **random forest**`

# %%
X=visa_df.drop("case_status",axis=1)
y=visa_df["case_status"]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=0)

# %%
from scipy import stats
selected_columns=["no_of_employees","yr_of_estab","prevailing_wage"]
z_scores=np.abs(stats.zscore(X_train[selected_columns]))
threshold=3
outlier_indices=np.where(z_scores>threshold)[0]
X_train=X_train.drop(X_train.index[outlier_indices])
y_train=y_train.drop(y_train.index[outlier_indices])

# %%
from sklearn.ensemble import RandomForestClassifier
RFtree=RandomForestClassifier()
RFtree.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred_rf=RFtree.predict(X_test)

# %%
from sklearn.metrics import accuracy_score,f1_score,precision_score,recall_score,classification_report
acc_rf=round(accuracy_score(y_test,y_pred_rf)*100,2)
f1score=round(f1_score(y_test,y_pred_rf),2)
pre_rf=round(precision_score(y_test,y_pred_rf),2)
recall=round(recall_score(y_test,y_pred_rf),2)
print("accuracy is",acc_rf)
print("f1score is",f1score)
print("precision is",pre_rf)
print("recall is",recall)
# Out:
# accuracy is 72.92
# f1score is 0.55
# precision is 0.62
# recall is 0.49

# %%
from sklearn.metrics import confusion_matrix,ConfusionMatrixDisplay
cmt=confusion_matrix(y_test,y_pred_rf)
disp=ConfusionMatrixDisplay(cmt,display_labels=[False,True])
disp.plot()
plt.grid(False)
plt.show()
tn,fp,fn,tp=confusion_matrix(y_test,y_pred_rf).ravel()
print("true negative:",tn)
print("false positive :",fp)
print("False negative:",fn)
print("True postive:",tp)
# Out:
# true negative: 2871
# false positive : 513
# False negative: 867
# True postive: 845

# %%
y_RF_pred_prob=RFtree.predict_proba(X_test)[:,1]   # Class-1 probabilities
fpr,tpr,threshold=roc_curve(y_test,y_RF_pred_prob) 
plt.plot(fpr,tpr)
plt.show()

# %%
dict1={'Accuracy':[acc_dt,acc_KNN,acc_log,acc_NB,acc_rf],
      "Precision":[precision_dt,precision_KNN,precision_log,precision_NB,pre_rf],
      "Recall":[recall_dt,recall_KNN,recall_log,recall_NB,recall],
      "F1-score":[f1_dt,f1_KNN,f1_log,f1_NB,f1score]}
pd.DataFrame(dict1,index=["dt","knn","logistic","navie bayes","random forest"])
# Out:
#                Accuracy  Precision  Recall  F1-score
# dt                64.64       0.48    0.50      0.49
# knn               62.42       0.41    0.26      0.31
# logistic          66.41       0.00    0.00      0.00
# navie bayes       68.70       0.68    0.13      0.22
# random forest     72.92       0.62    0.49      0.55
